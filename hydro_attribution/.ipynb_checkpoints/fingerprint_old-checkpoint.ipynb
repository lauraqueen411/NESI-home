# %% [markdown]
# Fingerprinting
#
# This workbook uses a IDL_python bridge to run fingerprinting analysis on seasonal runoff data across New Zealand. It defines functions which read previously created runoff datafiles and setup the data_obs, data_scen, and noise vectors. These vectors are then input into Daithi Stone's gendetec IDL code which returns the regression coefficients for the multiple linear regression problem as follows: data_obs = beta_est * data_scen + residual.
#
# Results are saved in ~/figures/fingerprinting/beta_est/ if using a single truncation and ""/scan_beta_est/ if depicting a range of truncation options.

# %%
import numpy as np
import pandas as pd
import xarray as xr
from functools import reduce
import matplotlib.pyplot as plt
from idlpy import *
from scipy import stats
import statsmodels.api as sm


import seaborn as sns
import cartopy.crs as ccrs
# Out:
# IDL 8.7.2 (linux x86_64 m64).
# (c) 2019, Harris Geospatial Solutions, Inc.
#
# Licensed for use by: NIWA - National Institute of Water and Atmospheric Research Ltd - Ashley
# License: 229483-BUF
# Expiration date: 31-Mar-2023
# A new version is available: IDL 8.8.3
# https://harrisgeospatial.flexnetoperations.com

# %%
df = pd.read_csv('/nesi/project/niwa00015/queenle/data/runoff/winter_obs.csv')
df = df.set_index('date')

# %%
df
# Out:
#             -35.550846 174.0  -37.04772 174.75  -37.04772 175.5  \
# date
# 1979-06-01     112627.645342       1632.430370     40015.076087
# 1980-06-01      76973.576087        606.697554     17108.836957
# 1981-06-01      71644.043478        722.882011     14927.021739
# 1982-06-01      39322.260870        318.055348      9998.239130
# 1983-06-01      46265.793478        390.933348      9134.271739
# 1984-06-01      44720.230099        565.740847      8940.847826
# 1985-06-01      58770.663043        427.456522     20805.467391
# 1986-06-01      46039.894277        541.633837     13912.760870
# 1987-06-01      41035.675935        320.104196     15919.684783
# 1988-06-01      57189.336957       1065.622076     30531.153623
# 1989-06-01      83352.750000        424.924054     20990.326087
# 1990-06-01      65733.004741        694.306570     23384.119565
# 1991-06-01      58413.423913        217.128489     12426.315217
# 1992-06-01      88210.462945        647.259924     19103.543478
# 1993-06-01      34778.167463        282.619696     14303.796618
# 1994-06-01      53028.869565        410.959772     14294.608696
# 1995-06-01      70779.228261        659.475652     17691.934783
# 1996-06-01      78774.448151       1137.111793     27716.141304
# 1997-06-01      74990.923913        927.687098     18709.619565
# 1998-06-01     144077.847826       1752.668978     34191.782609
# 1999-06-01      47432.065217        429.142076      6714.369565
# 2000-06-01      78017.000000        507.600522     29028.183561
# 2001-06-01      42103.108696        411.244402     11208.347826
# 2002-06-01      95037.967391       1192.545217     23156.989130
# 2003-06-01      69225.119565        698.370620     18290.434783
# 2004-06-01      47448.315217        545.106587     12080.989130
# 2005-06-01      55897.847826        608.143924     17666.478261
# 2006-06-01      55332.706522        629.786848     11917.717391
# 2007-06-01      90807.695399        952.747293     22743.630435
# 2008-06-01      92529.097826       1293.088891     30541.402174
# 2009-06-01      72308.913043        934.827032     19932.694577
# 2010-06-01      77062.641304        966.738793     27975.826087
# 2011-06-01      66568.869565        520.475500     16599.989130
# 2012-06-01      65244.076087        733.412565     23172.797101
# 2013-06-01      64832.793478        547.995511     13423.260870
# 2014-06-01     118984.765242        836.893902     22053.684783
# 2015-06-01      45842.336957        291.855391     10461.671385
# 2016-06-01      62544.336240        948.125424     20169.108696
# 2017-06-01      68962.244503        735.820404     19281.708454
# 2018-06-01      63118.513975        365.173913     21927.380435
# 2019-06-01      40276.195652        127.695652     10280.880435
#
#             -37.79616 175.5  -37.79616 177.75  -38.5446 174.75  \
# date
# 1979-06-01     76615.521739     221587.923913     14548.608696
# 1980-06-01     51686.445652     254248.728261     16219.913043
# 1981-06-01     50036.187469     155231.445652         0.000000
# 1982-06-01     33381.858696     122016.021739      9612.902174
# 1983-06-01     34622.065217     231562.076087      9668.858696
# 1984-06-01     37493.097826     291167.032609         0.000000
# 1985-06-01     54660.663043     222632.903197     15929.163043
# 1986-06-01     38764.315217     143868.445652     23332.494505
# 1987-06-01     34292.068216     127672.684783     11407.804348
# 1988-06-01     48686.706522     169386.989130         0.000000
# 1989-06-01     48427.554348     147795.934783     17182.885057
# 1990-06-01     54419.010870     290428.858696     21004.739130
# 1991-06-01     45234.649243     220958.695652     23940.804348
# 1992-06-01     51375.141304     304102.173913     27562.260870
# 1993-06-01     37691.092064     129828.293478     12766.943820
# 1994-06-01     56812.439855     226054.510870     23492.869565
# 1995-06-01     62411.565217     201047.057645     26536.858696
# 1996-06-01     69118.260870     207574.130435     23592.880435
# 1997-06-01     41437.108696     224311.663043     11628.478261
# 1998-06-01     73454.271739     403310.758399     25022.652174
# 1999-06-01     42106.282609     300436.097826     20010.771739
# 2000-06-01     54482.206522     223682.326087     14562.826087
# 2001-06-01     33514.054348     148338.065217     14565.000000
# 2002-06-01     51552.543478     327112.315217     21591.445652
# 2003-06-01     33717.152174     117333.902174     14873.152174
# 2004-06-01     45003.978261     312111.652174     22100.206522
# 2005-06-01     42140.804348     190391.673913     15641.380435
# 2006-06-01     39245.326087     373017.565217     22273.065217
# 2007-06-01     49612.902174     183013.152174     24483.478261
# 2008-06-01     63528.304348     280329.369565     31966.608696
# 2009-06-01     47320.760870     329325.141304     13580.739130
# 2010-06-01     54658.402174     302784.336957     23118.793478
# 2011-06-01     53205.000000     183543.000000     16500.163043
# 2012-06-01     61476.173788     257827.391304     17717.195652
# 2013-06-01     38870.293478     201819.478261     11729.967391
# 2014-06-01     53084.065217     303684.314700     18582.173913
# 2015-06-01     38188.336957     211895.630435     22483.195652
# 2016-06-01     46068.152174     148541.300000     21133.173913
# 2017-06-01     50277.510870     293275.195652     14342.271739
# 2018-06-01     56688.271739     210358.934783     17920.021739
# 2019-06-01     36443.869565     170696.586957     20500.945652
#
#             -38.5446 175.5  -38.5446 176.25  -38.5446 177.0  -38.5446 177.75  \
# date
# 1979-06-01    46465.239130     33277.717391    65948.782609     63727.217391
# 1980-06-01    45330.217391      9858.880435    48761.641304     68370.461509
# 1981-06-01    77689.978261     38258.228261   104681.988636     66828.608696
# 1982-06-01    36747.271739      7273.054348    38873.750000     25157.391304
# 1983-06-01    41792.489130     17591.532609    51317.858696     33044.880435
# 1984-06-01    54597.032609     25028.967391    55461.967391     60985.684783
# 1985-06-01    49057.391304     22880.673913    92758.108696     43133.639752
# 1986-06-01    71227.032609     27108.423913    60963.413043     39347.739130
# 1987-06-01    37059.989130     23525.967391    48451.695652     58248.793478
# 1988-06-01    89992.086957     27274.630435    89573.895302     41467.065217
# 1989-06-01    57243.750000     32946.621954    86899.880435     63509.336957
# 1990-06-01    73369.532609     33193.695652    95390.891063     49677.239130
# 1991-06-01    77044.532609     26465.945652    69028.684783     27165.500000
# 1992-06-01    93959.478261     28620.119565    75876.489130     46662.358696
# 1993-06-01    49241.141304     27044.532609    59661.880435     36706.141304
# 1994-06-01    86573.586957     33315.576087    86699.391304     37816.358696
# 1995-06-01    97176.260870     41657.228261    76026.423913     34716.489130
# 1996-06-01    84782.586957     38542.097826    62373.565217     46831.847826
# 1997-06-01    44429.434783     31573.076087    96038.985100     79036.543478
# 1998-06-01   100346.815217     44601.163043    67849.054348     45251.391304
# 1999-06-01    62578.652174     28937.054348    63404.782609     36609.565217
# 2000-06-01    52700.391304     24640.902174    72168.804348     41739.847826
# 2001-06-01    45459.402174     23292.804348    53188.652174     33999.858696
# 2002-06-01    75794.826087     33298.358696    93539.554348     54096.771739
# 2003-06-01    43654.119565     20887.173913    60543.065217     58475.434783
# 2004-06-01    82769.217391     46457.173913   130710.032609     66078.423913
# 2005-06-01    46637.021739     26244.445652    55655.250000     41131.663043
# 2006-06-01    68540.391304     39823.434783   116126.641304     74149.445652
# 2007-06-01    70466.043478     25093.315217    72081.597826     30775.369565
# 2008-06-01   106711.652174     33286.043478   111144.141304     42816.152174
# 2009-06-01    50594.500000     24172.097826    84463.217391     88726.489130
# 2010-06-01    70841.130435     32455.260870   121824.695652     66425.619565
# 2011-06-01    66135.304348     44186.130435    80891.434783     52505.293478
# 2012-06-01    68912.934783     32531.630435    63745.489130     60048.510870
# 2013-06-01    42890.967391     20165.358696    44355.543478     54289.847826
# 2014-06-01    60706.402174     18878.750000    53313.630435     51707.500000
# 2015-06-01    74459.902174     24744.086957    60375.804348     27603.836957
# 2016-06-01    79262.956522     31691.652174    99334.597826     26769.021739
# 2017-06-01    71548.739130     52226.771739    96177.970078     44831.151208
# 2018-06-01    73781.586957     39986.097826    65709.391304     72045.445652
# 2019-06-01    71618.673913     28610.728261    46712.434783     18926.521739
#
#             ...  -44.532104 169.5  -44.532104 171.0  -45.28054 168.0  \
# date        ...
# 1979-06-01  ...      63491.521739        236.717391    251258.815217
# 1980-06-01  ...     110123.489130        472.510870    387098.380435
# 1981-06-01  ...      82459.804348        402.391304    184367.043478
# 1982-06-01  ...      78153.706522         86.054348    246824.402174
# 1983-06-01  ...     111798.195652        344.989130    324544.108696
# 1984-06-01  ...      91045.010870        202.478261    298968.322634
# 1985-06-01  ...      96557.152174        198.206522    255367.184783
# 1986-06-01  ...     105040.119565          0.000000    340492.869565
# 1987-06-01  ...     101324.108696        284.532609    352204.380435
# 1988-06-01  ...      98086.010870        214.032609    377151.869565
# 1989-06-01  ...      83947.369565        224.739130    281977.942110
# 1990-06-01  ...      83589.184783        595.619565    301868.641304
# 1991-06-01  ...      82329.826837        241.500000    352829.978261
# 1992-06-01  ...      61765.423913          0.000000    281728.760870
# 1993-06-01  ...     104773.184783        104.619565    393858.956522
# 1994-06-01  ...      85611.548281        511.630435    375731.032609
# 1995-06-01  ...      56949.510870        383.434783    258519.760870
# 1996-06-01  ...      41360.706522        382.315217    231033.826087
# 1997-06-01  ...      74163.902174        203.113636    298914.641304
# 1998-06-01  ...     109654.902174          0.000000    372884.304348
# 1999-06-01  ...      58160.684783        264.630435    269184.978261
# 2000-06-01  ...     145911.445652        425.282609    366241.423913
# 2001-06-01  ...      60723.532609        210.543478    277335.910870
# 2002-06-01  ...      87722.434783        225.608696    399321.478261
# 2003-06-01  ...      71588.858696         80.021739    364235.456522
# 2004-06-01  ...      91066.880435        173.967391    370119.913043
# 2005-06-01  ...      54591.260870        242.739130    272027.500000
# 2006-06-01  ...      57138.478994        337.358696    245307.217391
# 2007-06-01  ...      71472.343287        177.271739    326603.826087
# 2008-06-01  ...      54361.554348        342.891304    223806.326087
# 2009-06-01  ...      88029.967391        297.576087    295564.108696
# 2010-06-01  ...      78019.010870        443.521739    207020.771739
# 2011-06-01  ...      50410.880435        174.206522    257204.445652
# 2012-06-01  ...      62372.652174        926.826087    222927.206522
# 2013-06-01  ...     125373.016425        813.630435    410421.858696
# 2014-06-01  ...     120359.336957        277.586957    369794.739130
# 2015-06-01  ...      96862.108696        166.347826    382188.869565
# 2016-06-01  ...      88141.206522        198.086957    337832.489130
# 2017-06-01  ...      68324.554348        614.695652    258952.304348
# 2018-06-01  ...      24996.717391        184.119565     50950.163043
# 2019-06-01  ...      26296.250000        203.565217     50980.684783
#
#             -45.28054 168.75  -45.28054 170.25  -46.028976 167.25  \
# date
# 1979-06-01      27826.347826       1793.858696       11436.130435
# 1980-06-01      94391.500000       7463.065217       21203.717391
# 1981-06-01      37836.760870       4322.641304        9613.532609
# 1982-06-01      32686.456522          0.000000       13485.880435
# 1983-06-01      73712.510870       3735.173913       15278.445652
# 1984-06-01      59499.695652       2462.054348       12200.260870
# 1985-06-01      28554.565217       1345.739130       11707.097826
# 1986-06-01      65262.853893       5328.543478       17924.521739
# 1987-06-01      62005.637376       3231.217391       17306.054348
# 1988-06-01      56311.641304       1628.989130       18552.597826
# 1989-06-01      60639.934783          0.000000       10670.826087
# 1990-06-01      28372.739130       6842.326087       11170.054348
# 1991-06-01      51757.271739       2189.532609       14390.358696
# 1992-06-01      40026.891304       3836.380435       14181.945652
# 1993-06-01      37402.489130       1117.086957       14904.956522
# 1994-06-01      50996.293478       6008.967391       19219.760870
# 1995-06-01      57223.956522       4068.750000       13295.652174
# 1996-06-01      57999.804348       3440.304348       14050.652174
# 1997-06-01      48605.206522       1667.086957       14117.869565
# 1998-06-01      55185.184783       1131.380435       13944.380435
# 1999-06-01      56550.484190       2870.510870       12863.804348
# 2000-06-01      57086.006595       3367.010870       14709.782609
# 2001-06-01      51991.402174       2716.184783       13257.521739
# 2002-06-01      72161.684783       3306.717391       20210.478261
# 2003-06-01      38408.543478        812.652174       15144.152174
# 2004-06-01      60661.510870       2037.576087       15571.293478
# 2005-06-01      48411.739130       2649.630435       13942.206522
# 2006-06-01      46931.152174          0.000000       14262.771739
# 2007-06-01      47437.908769       2386.815217       13248.260870
# 2008-06-01      24827.141304       3250.304348       12473.543478
# 2009-06-01      38189.043478       2686.695652       11993.945652
# 2010-06-01      54380.413043       3353.000000        9648.619565
# 2011-06-01      42712.163043       1065.086957       12673.739130
# 2012-06-01      46100.141304       5936.782609       11944.673913
# 2013-06-01      90858.750717          0.000000       17824.250000
# 2014-06-01      69701.554348       3459.782609       13208.945652
# 2015-06-01      87329.630435       2773.782609       18199.717391
# 2016-06-01      56742.717391       3415.478261       11895.076087
# 2017-06-01      55621.315217       2803.369565       10194.608696
# 2018-06-01      55465.728261       1778.641304           0.000000
# 2019-06-01      60796.989130       2218.880435           0.000000
#
#             -46.028976 168.0  -46.028976 168.75  -46.028976 169.5  \
# date
# 1979-06-01       7327.510870        5310.934783      27505.880435
# 1980-06-01      14792.890110       18888.771739      73490.672337
# 1981-06-01       6546.815217        8900.250000      34756.533413
# 1982-06-01          0.000000        9677.706522      36252.747348
# 1983-06-01      14143.054348       12171.521739      49374.374272
# 1984-06-01       5932.348315        9222.760870      41526.177185
# 1985-06-01       5056.195652        5385.423913      20271.379391
# 1986-06-01      10678.206522       12798.065217      51411.119793
# 1987-06-01      10768.241379       11280.108696      48245.586957
# 1988-06-01      11615.706522       12074.076087      58224.238565
# 1989-06-01       7902.604651        9125.717391      34784.788587
# 1990-06-01       6122.500000        4620.315217      18676.330685
# 1991-06-01      10469.543478       13668.826087      44678.532609
# 1992-06-01       7843.630435       10853.217391         14.426000
# 1993-06-01       8216.217391        6133.097826      28033.463630
# 1994-06-01      11572.913043       10531.663043      55366.473750
# 1995-06-01       8180.967391       10688.934783      57779.231674
# 1996-06-01       8245.902174       11237.554348      42638.837315
# 1997-06-01       7939.065217        9396.130435      38581.788033
# 1998-06-01       8037.782609        7992.402174      28359.761196
# 1999-06-01       8146.413043        9150.228261      36742.336924
# 2000-06-01       9714.406977        5823.163043      32141.017522
# 2001-06-01       7860.588889        7890.413043      41932.565163
# 2002-06-01       9344.043478       10743.521739      52852.406576
# 2003-06-01       8018.329545        7165.423913      29187.063761
# 2004-06-01       9368.054348        9887.695652      45026.650370
# 2005-06-01       7182.086957        9994.032609      47813.061630
# 2006-06-01       8067.641304        7348.717391      29443.128511
# 2007-06-01       7712.760870        8497.119565      40842.629652
# 2008-06-01       7763.307692       10563.913043      47523.687978
# 2009-06-01       7599.423913        5221.336957      27744.635783
# 2010-06-01       6280.584270        7607.880435      33110.729054
# 2011-06-01       6775.597826        7929.445652      34334.716098
# 2012-06-01       6936.021739        6720.293478      33604.653598
# 2013-06-01      12797.318681        8984.195652      47592.432533
# 2014-06-01      10596.043478       12612.206522      41146.107402
# 2015-06-01      12532.673913       15897.391304      62217.319674
# 2016-06-01       8511.750000        9594.304348      39042.878174
# 2017-06-01       7234.173913        8961.706522      42770.881239
# 2018-06-01      10386.967391        9650.858696      33445.607174
# 2019-06-01       9539.000000       12120.054348      43322.293315
#
#             -46.028976 170.25
# date
# 1979-06-01         794.271739
# 1980-06-01        2200.478261
# 1981-06-01        2115.630435
# 1982-06-01           0.000000
# 1983-06-01           0.000000
# 1984-06-01         705.815217
# 1985-06-01           0.000000
# 1986-06-01        1137.144444
# 1987-06-01         764.511111
# 1988-06-01         530.391304
# 1989-06-01         595.673913
# 1990-06-01        1074.282609
# 1991-06-01         800.684783
# 1992-06-01        1070.184783
# 1993-06-01           0.000000
# 1994-06-01        1341.750000
# 1995-06-01        1262.228261
# 1996-06-01        1075.152174
# 1997-06-01         516.336957
# 1998-06-01         272.619565
# 1999-06-01         768.782609
# 2000-06-01        1565.782609
# 2001-06-01         884.739130
# 2002-06-01         974.445652
# 2003-06-01         365.315217
# 2004-06-01         750.347826
# 2005-06-01         394.054348
# 2006-06-01         590.880435
# 2007-06-01         990.163043
# 2008-06-01        1288.586957
# 2009-06-01         894.217391
# 2010-06-01        1105.695652
# 2011-06-01         473.282609
# 2012-06-01        1400.815217
# 2013-06-01        1746.054348
# 2014-06-01         643.065217
# 2015-06-01        1338.945652
# 2016-06-01         697.684783
# 2017-06-01           0.000000
# 2018-06-01         351.804348
# 2019-06-01         383.791209
#
# [41 rows x 41 columns]

# %%
cell_list = [
       '-35.5508 174.0', '-37.0477 174.75', '-37.0477 175.5',
       '-37.7961 175.5', '-37.7961 177.75', '-38.5446 174.75',
       '-38.5446 175.5', '-38.5446 176.25', '-38.5446 177.0',
       '-38.5446 177.75', '-39.2930 174.0', '-39.2930 174.75',
       '-39.2930 175.5', '-39.2930 176.25', '-40.0414 176.25',
       '-40.7899 172.5', '-40.7899 175.5', '-40.7899 176.25',
       '-41.5383 172.5', '-41.5383 173.25', '-41.5383 174.0',
       '-42.2867 171.75', '-42.2867 172.5', '-42.2867 173.25',
       '-43.0352 171.0', '-43.0352 172.5', '-43.7836 169.5',
       '-43.7836 170.25', '-43.7836 171.0', '-43.7836 171.75',
       '-44.5321 168.75', '-44.5321 169.5', '-44.5321 171.0',
       '-45.2805 168.0', '-45.2805 168.75', '-45.2805 170.25',
       '-46.0289 167.25', '-46.0289 168.0', '-46.0289 168.75',
       '-46.0289 169.5', '-46.0289 170.25']

# %%
file_name = 'mrro_Lmon-ANZ_ECHAM5-4_All-Hist_est1_v1-0_ens01_197901-201902.nc'
file_path = '../stoneda/data-for-laura/C20C/NOAA-ESRLandCIRES/ECHAM5-4/All-Hist/est1/v1-0/mon/land-ANZ/mrro/ens01/' + file_name

example_member = xr.open_dataset(file_path)
example_member = example_member['mrro'].sel(time=slice('1979-03-01','2019-03-01')).resample(time='QS-DEC').mean()
example_da = example_member.sel(time=example_member.time.dt.month.isin([3]))

example_stacked = example_da.stack(grid_cell=('lat','lon'))

mask_array = np.zeros(example_stacked.shape)

for i,cell in enumerate(example_stacked.indexes['grid_cell']):
    
    coords = str(cell[0])[:8] + " " + str(cell[1])
        
    if coords in cell_list:
        mask_val = 1
    else:
        mask_val = 0
    for k in range(len(example_da.time.values)):
        mask_array[k][i] = mask_val
        
mask_array.shape
# Out:
# (40, 598)

# %%
file_name = 'mrro_Lmon-ANZ_ECHAM5-4_All-Hist_est1_v1-0_ens01_197901-201902.nc'
file_path = '../stoneda/data-for-laura/C20C/NOAA-ESRLandCIRES/ECHAM5-4/All-Hist/est1/v1-0/mon/land-ANZ/mrro/ens01/' + file_name

ens_mem = xr.open_dataset(file_path)

# grab time window, resample to seasonal
ens_mem = ens_mem['mrro'].sel(time=slice('1979-03-01','2019-03-01')).resample(time='QS-DEC').mean()
# select season
season_da = ens_mem.sel(time=ens_mem.time.dt.month.isin([3]))
# stack lat, lon
season_da = season_da.stack(grid_cell=('lat','lon'))
# add mask coordinate
season_da.coords['mask'] = (('time','grid_cell'),mask_array)
# mask runoff to only cells with observed records
season_da = season_da.where(season_da.mask == 1,drop=True)

# take log of entire data array
#log_da = np.log(season_da)

# subtract temporal mean from each cell
mean_removed = season_da - season_da.mean(dim='time')

plt.figure(figsize=(10,8))
ax=plt.axes(projection=ccrs.PlateCarree())

im = ax.scatter([cell[1] for cell in mean_removed.indexes['grid_cell']],[cell[0] for cell in mean_removed.indexes['grid_cell']],c=mean_removed.mean('time').values,cmap='coolwarm_r',marker='s',s=150)

ax.coastlines(resolution='50m', color='black', linewidth=1)
ax.set_xlim([164,180])

plt.colorbar(im)

plt.show()

#log_mean_removed.values.shape

# %%
'''
A function which reads season_obs.csv and creates a seasonal data_obs vector. 
season: a string in ['fall','winter','spring','summer']
'''

def get_obs_data(scen, season):
    
    df = pd.read_csv('data/runoff/' + season + '_obs.csv')
    df = df.set_index('date')
    #df = df.mask(df==0).fillna(df.mean())
    
    
    # take log only
    #df = np.log10(df)

    # subtract mean only
    #df = df - df.mean()
    
    # take log, subtract mean
    #df = np.log10(df)
    #df = df - df.mean()
    
    # divide by mean and subtract 1
    df = df / df.mean()
    df = df - 1
    
    
    data_array = np.reshape(df.values,40*41)
    #print(df.columns)
    
    return(data_array)

# %%
'''
A function which calculates the noise array of a specific scenario. The array has 50x41 dimensions because there
are 50 ensemble members and 41 grid cells. Each ensemble member has its own noise vector. 

season: a string in ['fall','winter','spring','summer']
scen: a string in ['all','nat'] 
typ: a string in ['annual','decadal','trend'] which determines the temporal scale of the return vector. If 'trend'
     is chosen, the kendall-tau tau value is recorded for each cell.
scen_data: the respective (all or nat) data_scen vector which is the average of ensemble members in the appropriate
           unit (annual, decadal, trend seasonal runoff)
'''

def get_mean_and_noise(season,scen,typ):
    
    if scen == 'all':
        path = '../stoneda/data-for-laura/C20C/NOAA-ESRLandCIRES/ECHAM5-4/All-Hist/est1/v1-0/mon/land-ANZ/mrro/ens'
        file_name_setup = ['mrro_Lmon-ANZ_ECHAM5-4_All-Hist_est1_v1-0_ens','_197901-201902.nc']
    if scen == 'nat':
        path = '../stoneda/data-for-laura/C20C/NOAA-ESRLandCIRES/ECHAM5-4/Nat-Hist/obs-trend-1880s-est1/v1-0/mon/land-ANZ/mrro/ens'
        file_name_setup = ['mrro_Lmon-ANZ_ECHAM5-4_Nat-Hist_obs-trend-1880s-est1_v1-0_ens','_197901-201912.nc']
        
    ens_members = []
    
    for ens_mem in range(1,51):
        number = '0' + str(ens_mem) if ens_mem < 10 else str(ens_mem)
        file_name = file_name_setup[0]+number+file_name_setup[1]
        file_path = path + number + "/" + file_name

        ens_mem = xr.open_dataset(file_path)
        
        # grab time window, resample to seasonal
        ens_mem = ens_mem['mrro'].sel(time=slice('1979-03-01','2019-03-01')).resample(time='QS-DEC').mean()
        # select season
        season_da = ens_mem.sel(time=ens_mem.time.dt.month.isin([season]))
        # stack lat, lon
        season_da = season_da.stack(grid_cell=('lat','lon'))
        # add mask coordinate
        season_da.coords['mask'] = (('time','grid_cell'),mask_array)
        # mask runoff to only cells with observed records
        season_da = season_da.where(season_da.mask == 1,drop=True)
        
        da = season_da
        
        # take log only
        #da = np.log10(season_da)
        
        # remove local mean only
        #da = season_da - season_da.mean(dim='time')
        
        # take log, subtract mean
        #da = np.log10(season_da)
        #da = da - da.mean(dim='time')
        
        # divide by mean and subtract 1
        #local_means = da.mean(dim='time').sel({"grid_cell":( -39.29303741455078, 174.75)})
        #print(da.indexes["grid_cell"])
        #print(local_means)
        #print(da.sel({"grid_cell":( -39.29303741455078, 174.75)}))
        da = da / da.mean(dim='time')
        #print(da.sel({"grid_cell":( -39.29303741455078, 174.75)}))
        da = da - 1
        
        # values shape 40,41: (time,space)
        data_array = da.values.reshape(40*41)
                        
        ens_members.append(data_array)
        
    ens_mean = np.mean(np.array(ens_members),axis=0)
    
    #print(ens_mean.shape)
            
    noise = []
    for i,member in enumerate(ens_members):
        difference = np.subtract(member,ens_mean)
        noise.append(difference)
        
    
    #print(np.array(noise).shape)
    
    return([np.array(ens_mean), np.array(noise), np.array(ens_members)])

# %%
'''
MAIN PROGRAM

Create a seasonal plot of the regression coefficients using an array of trunctions.
The plots are saved in ~/figures/fingerprinting/scan_beta_est.
'''

fig,axs = plt.subplots(4,2, figsize=(20,20),squeeze=True)#, sharex=True,sharey=True)

axs = axs.flatten()

season_residuals = []
season_est_obs = []
season_obs = []

seasons = ['summer','fall','winter','spring']
for i in range(4):
    
    season = seasons[i]
        
    season_n = {'fall':3,'winter':6,'spring':9,'summer':12}[season]
    IDL.retall
    
    data_obs = get_obs_data('obs',season)
    
    all_ens_mean,noise_all,all_ens = get_mean_and_noise(season_n,'all','annual')
    nat_ens_mean,noise_nat,nat_ens = get_mean_and_noise(season_n,'nat','annual')
    
    data_noise_1 = np.concatenate((noise_all[:25],noise_nat[:25]))
    data_noise_2 = np.concatenate((noise_all[25:],noise_nat[25:]))
    
    data_scen = np.array([all_ens_mean,nat_ens_mean])
    
    trunc = np.array([i for i in range(3,48)])
    #trunc = 25

    B = axs[i].boxplot(data_obs)
    
    #a = min(data_obs)
    #b = max(data_obs)
    
    a=B['whiskers'][0].get_ydata()[1]
    b=B['whiskers'][1].get_ydata()[1]
    
    axs[i].clear()
    
    def scale(ary):
        mn = min(ary.flatten())
        mx = max(ary.flatten())
        
        new_ary = np.zeros(ary.shape)
        for i in range(ary.shape[0]):
            for j in range(ary.shape[1]):
                val = ary[i][j]
                new_ary[i][j] = (((b-a)*(val-mn))/(mx-mn))+a
                    
        return new_ary
        
    new_noise_1 = scale(data_noise_1)
    new_noise_2 = scale(data_noise_2)    
    
    IDL.data_obs = data_obs
    IDL.data_scen = data_scen
    IDL.data_noise_1 = new_noise_1
    IDL.data_noise_2 = new_noise_2
    IDL.trunc = trunc
    IDL.scan_beta_est = []
    IDL.scan_p_resid = []
    IDL.scan_resid_sumsq = []
    IDL.p_resid = []
    IDL.resid_sumsq = []
    IDL.noise_singval = []
    IDL.z_best = []

    IDL.run("gendetec, data_obs, data_scen, data_noise_1, beta_est, scan_resid_sumsq=scan_resid_sumsq, \
            data_noise_2=data_noise_2,transform=['1*0','1*0+1*1'], trunc=trunc, scan_beta_est=scan_beta_est,\
            scan_p_resid=scan_p_resid,noise_singval=noise_singval,z_best=z_best")

    #IDL.run("gendetec, data_obs, data_scen, data_noise_1, beta_est, \
    #        data_noise_2=data_noise_2,transform=['1*0','1*0+1*1'], trunc=trunc,\
    #        noise_singval=noise_singval,z_best=z_best")
    
    beta_est = IDL.beta_est
    scan_beta_est = IDL.scan_beta_est
    scan_p_resid = IDL.scan_p_resid
    scan_resid_sumsq = IDL.scan_resid_sumsq
    noise_singval = IDL.noise_singval
    z_best = IDL.z_best
    
    est_obs = z_best[2]
        
    # add mean back to z_best
    #est_obs = [z_best[2][i] + np.mean(data_obs) for i in range(len(z_best[2]))]
    
    # get residual in log space
    residual = data_obs - est_obs
    
        
    #season_residuals.append(residual)
    #season_est_obs.append(est_obs)
    #season_obs.append(data_obs)
    
    axs[i].boxplot([new_noise_1,new_noise_2,est_obs,data_obs,all_ens[25],all_ens.flatten(),all_ens_mean,nat_ens_mean,data_noise_1.flatten(),data_noise_2.flatten()],sym='.',vert=False,labels=['new_noise_1','new_noise_2','est_obs','Obs','All-1 mem','All-all mems','All-ens mean','Nat-ens mean','Noise_1','Noise_2'])

    axs[i+4].scatter([i for i in range(len(residual))],residual)
    axs[i+4].set_ylim(min(residual),max(residual))
    
    axs[i].set_title(season)
    axs[i+4].set_title(season)

# %%
B = plt.boxplot(data_obs)

#a,b = item.get_ydata()[1] for item in B['whiskers']

print(B['whiskers'][0].get_ydata()[1])
print(B['whiskers'][1].get_ydata()[1])

plt.clf()
# Out:
# -0.3444262997891263
# 0.3433817348824002

# %%
'''
MAIN PROGRAM

Create a seasonal plot of the regression coefficients using an array of trunctions.
The plots are saved in ~/figures/fingerprinting/scan_beta_est.
'''

fig,axs = plt.subplots(2,2, figsize=(12,10))#, sharex=True,sharey=True)

season_residuals = []
season_est_obs = []
season_obs = []

seasons = ['summer','fall','winter','spring']
for i,ax in enumerate(axs.flatten()):
    
    season = seasons[i]
        
    season_n = {'fall':3,'winter':6,'spring':9,'summer':12}[season]
    IDL.retall
    
    data_obs = get_obs_data('obs',season)
    
    all_ens_mean,noise_all,all_ens = get_mean_and_noise(season_n,'all','annual')
    nat_ens_mean,noise_nat,nat_ens = get_mean_and_noise(season_n,'nat','annual')
    
    data_noise_1 = np.concatenate((noise_all[:25],noise_nat[:25]))
    data_noise_2 = np.concatenate((noise_all[25:],noise_nat[25:]))
    
    data_scen = np.array([all_ens_mean,nat_ens_mean])
    
    trunc = np.array([i for i in range(3,48)])
    #trunc = 25
    
    B = ax.boxplot(data_obs)
    
    #a = min(data_obs)
    #b = max(data_obs)
    
    a=B['whiskers'][0].get_ydata()[1]
    b=B['whiskers'][1].get_ydata()[1]
        
    ax.clear()
    
    def scale(ary):
        mn = min(ary.flatten())
        mx = max(ary.flatten())
        
        new_ary = np.zeros(ary.shape)
        for i in range(ary.shape[0]):
            for j in range(ary.shape[1]):
                val = ary[i][j]
                new_ary[i][j] = (((b-a)*(val-mn))/(mx-mn))+a
                    
        return new_ary
        
    new_noise_1 = scale(data_noise_1)
    new_noise_2 = scale(data_noise_2)    
    
    IDL.data_obs = data_obs
    IDL.data_scen = data_scen
    IDL.data_noise_1 = new_noise_1
    IDL.data_noise_2 = new_noise_2
    IDL.trunc = trunc
    IDL.scan_beta_est = []
    IDL.scan_p_resid = []
    IDL.scan_resid_sumsq = []
    IDL.p_resid = []
    IDL.resid_sumsq = []
    IDL.noise_singval = []
    IDL.z_best = []

    IDL.run("gendetec, data_obs, data_scen, data_noise_1, beta_est, scan_resid_sumsq=scan_resid_sumsq, \
            data_noise_2=data_noise_2,transform=['1*0','1*0+1*1'], trunc=trunc, scan_beta_est=scan_beta_est,\
            scan_p_resid=scan_p_resid,noise_singval=noise_singval,z_best=z_best")

    #IDL.run("gendetec, data_obs, data_scen, data_noise_1, beta_est, \
    #        data_noise_2=data_noise_2,transform=['1*0','1*0+1*1'], trunc=trunc,\
    #        noise_singval=noise_singval,z_best=z_best")
    
    beta_est = IDL.beta_est
    scan_beta_est = IDL.scan_beta_est
    scan_p_resid = IDL.scan_p_resid
    scan_resid_sumsq = IDL.scan_resid_sumsq
    noise_singval = IDL.noise_singval
    z_best = IDL.z_best
    
    for i in range(len(scan_beta_est)):

        beta_est = scan_beta_est[i]
        
        best_1,low_1,up_1 = beta_est[0][0],beta_est[1][0],beta_est[2][0]
        best_2,low_2,up_2 = beta_est[0][1],beta_est[1][1],beta_est[2][1]

        ax.scatter([i for j in range(3)],[low_1,best_1,up_1],c='blue',label='ant' if i == 0 else '')
        ax.scatter([i for j in range(3)],[low_2,best_2,up_2],c='red',alpha=0.7,label='nat' if i == 0 else '')
        #ax.text(0.4,0.9,'p_resid = ' + str(p_resid[i]),transform=ax.transAxes)
        ax.vlines(i,low_1,up_1,colors=['blue'])
        ax.vlines(i,low_2,up_2,colors=['red'])
        ax.axhline(0,-0.5,1.5)
        ax.axhline(1,-0.5,1.5)
    #ax.set_xlim(-0.5,1.5)
    #ax.set_ylim(-10,5)
    
    
    ax.set_title(season + ', Trunc = ' + str(IDL.trunc))
    #ax.set_ylim(-0.0001, 0.00027)
    #if season != 'summer':
    #    ax.set_ylim(0,0.4)
    ax.legend()

# %%
'''
MAIN PROGRAM

Create a seasonal plot of the regression coefficients using an array of trunctions.
The plots are saved in ~/figures/fingerprinting/scan_beta_est.
'''

fig,axs = plt.subplots(2,2, figsize=(12,10))#, sharex=True,sharey=True)

season_residuals = []
season_est_obs = []
season_obs = []

seasons = ['summer','fall','winter','spring']
for i,ax in enumerate(axs.flatten()):
    
    season = seasons[i]
        
    season_n = {'fall':3,'winter':6,'spring':9,'summer':12}[season]
    IDL.retall
    
    data_obs = get_obs_data('obs',season)
    
    all_ens_mean,noise_all,all_ens = get_mean_and_noise(season_n,'all','annual')
    nat_ens_mean,noise_nat,nat_ens = get_mean_and_noise(season_n,'nat','annual')
    
    data_noise_1 = np.concatenate((noise_all[:25],noise_nat[:25]))
    data_noise_2 = np.concatenate((noise_all[25:],noise_nat[25:]))
    
    data_scen = np.array([all_ens_mean,nat_ens_mean])
    
    trunc = np.array([i for i in range(3,48)])
    #trunc = 25
    
    B = ax.boxplot(data_obs)
    
    #a = min(data_obs)
    #b = max(data_obs)
    
    a=B['whiskers'][0].get_ydata()[1]
    b=B['whiskers'][1].get_ydata()[1]
        
    ax.clear()
    
    def scale(ary):
        mn = min(ary.flatten())
        mx = max(ary.flatten())
        
        new_ary = np.zeros(ary.shape)
        for i in range(ary.shape[0]):
            for j in range(ary.shape[1]):
                val = ary[i][j]
                new_ary[i][j] = (((b-a)*(val-mn))/(mx-mn))+a
                    
        return new_ary
        
    new_noise_1 = scale(data_noise_1)
    new_noise_2 = scale(data_noise_2)    
    
    data_noise_1 = new_noise_1
    data_noise_2 = new_noise_2
    
    
    IDL.data_obs = data_obs
    IDL.data_scen = data_scen
    IDL.data_noise_1 = data_noise_1
    IDL.data_noise_2 = data_noise_2
    IDL.trunc = trunc
    IDL.scan_beta_est = []
    IDL.scan_p_resid = []
    IDL.scan_resid_sumsq = []
    IDL.p_resid = []
    IDL.resid_sumsq = []
    IDL.noise_singval = []
    IDL.z_best = []

    IDL.run("gendetec, data_obs, data_scen, data_noise_1, beta_est, scan_resid_sumsq=scan_resid_sumsq, \
            data_noise_2=data_noise_2,transform=['1*0','1*0+1*1'], trunc=trunc, scan_beta_est=scan_beta_est,\
            scan_p_resid=scan_p_resid,noise_singval=noise_singval,z_best=z_best")

    #IDL.run("gendetec, data_obs, data_scen, data_noise_1, beta_est, \
    #        data_noise_2=data_noise_2,transform=['1*0','1*0+1*1'], trunc=trunc,\
    #        noise_singval=noise_singval,z_best=z_best")
    
    beta_est = IDL.beta_est
    scan_beta_est = IDL.scan_beta_est
    scan_p_resid = IDL.scan_p_resid
    scan_resid_sumsq = IDL.scan_resid_sumsq
    noise_singval = IDL.noise_singval
    z_best = IDL.z_best
    
    for i in range(len(scan_beta_est)):

        beta_est = scan_beta_est[i]
        
        best_1,low_1,up_1 = beta_est[0][0],beta_est[1][0],beta_est[2][0]
        best_2,low_2,up_2 = beta_est[0][1],beta_est[1][1],beta_est[2][1]

        ax.scatter([i for j in range(3)],[low_1,best_1,up_1],c='blue',label='ant' if i == 0 else '')
        ax.scatter([i for j in range(3)],[low_2,best_2,up_2],c='red',alpha=0.7,label='nat' if i == 0 else '')
        #ax.text(0.4,0.9,'p_resid = ' + str(p_resid[i]),transform=ax.transAxes)
        ax.vlines(i,low_1,up_1,colors=['blue'])
        ax.vlines(i,low_2,up_2,colors=['red'])
        ax.axhline(0,-0.5,1.5)
        ax.axhline(1,-0.5,1.5)
    #ax.set_xlim(-0.5,1.5)
    #ax.set_ylim(-10,5)
    
    
    ax.set_title(season + ', Trunc = ' + str(IDL.trunc))
    #ax.set_ylim(-0.0001, 0.00027)
    #if season != 'summer':
    #    ax.set_ylim(0,0.4)
    ax.legend()

# %%
fig,axs = plt.subplots(2,2, figsize=(12,10))#, sharex=True,sharey=True)

seasons = ['summer','fall','winter','spring']
for i,ax in enumerate(axs.flatten()):
    
    season = seasons[i]
    season_n = {'fall':3,'winter':6,'spring':9,'summer':12}[season]
    
    data_obs = season_obs[i]
    data_est_obs = season_est_obs[i]
    data_all,noise_all = get_mean_and_noise(season_n,'all','annual')
    
    ax.boxplot([data_obs,data_all,data_est_obs],vert=False,labels=['Observed','All-forcings','estimated_obs'])
    #ax.hist(data_obs,bins,alpha=0.8,label='observed flow')
    #ax.hist(data_scen[0],bins,alpha=0.7,label='All-forcings runoff')
    
    #ax.set_xticks([0.0001*i for i in range(5)])
    #ax.text(0.0002,1.5,'difference of means:\n' + str(np.mean(data_obs) - np.mean(data_scen[0])))

    #ax.set_xlim(-0.0003,0.0003)
    #ax.text(0.00015,600,'difference of means:\n' + str(np.mean(data_obs) - np.mean(data_scen[0])))

    
    #if i == 0:
    #    ax.legend()

# %%
seasons = ['winter']#,'spring','summer''fall',]
scen = ['obs','nat','anth']
fig,axs = plt.subplots(2,2,subplot_kw={'projection': ccrs.PlateCarree()},figsize=(20,10))

obs_df = pd.read_csv('data/runoff/' + season + '_obs.csv')
obs_df = obs_df.set_index('date')


for s,ax in enumerate(axs.flatten()):
    
    residual = season_residuals[s].reshape(41,40)
    
    lons = [float(c.split(' ')[1]) for c in obs_df.columns]
    lats = [float(c.split(' ')[0]) for c in obs_df.columns]

    vals = []
    for cell in range(41):
        vals.append(np.mean(residual[cell]))

    im = ax.scatter(lons,lats,c=vals,cmap='GnBu',marker='s',s=150,vmin=0,vmax=0.00003) 
    fig.colorbar(im,ax=ax,label='kg*m^-2*s-1')
    ax.coastlines()
