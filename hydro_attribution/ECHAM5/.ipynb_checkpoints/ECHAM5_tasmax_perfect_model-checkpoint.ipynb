# %% [markdown]
# Fingerprinting
#
# This workbook uses a IDL_python bridge to run fingerprinting analysis on seasonal runoff data across New Zealand. It defines functions which read previously created runoff datafiles and setup the data_obs, data_scen, and noise vectors. These vectors are then input into Daithi Stone's gendetec IDL code which returns the regression coefficients for the multiple linear regression problem as follows: data_obs = beta_est * data_scen + residual.
#
# Results are saved in ~/figures/fingerprinting/beta_est/ if using a single truncation and ""/scan_beta_est/ if depicting a range of truncation options.

# %%
import numpy as np
import pandas as pd
import xarray as xr
from functools import reduce
import matplotlib.pyplot as plt
from idlpy import *
from scipy import stats
import statsmodels.api as sm


import seaborn as sns
import cartopy.crs as ccrs
# Out:
# IDL 8.7.2 (linux x86_64 m64).
# (c) 2019, Harris Geospatial Solutions, Inc.
#
# A new version is available: IDL 8.9
# https://www.l3harrisgeospatial.com/Product-Downloads/
#
# Licensed for use by: NIWA - National Institute of Water and Atmospheric Research Ltd - Ashley
# License: 229483-BUF
# Expiration date: 31-Mar-2024

# %%
def get_obs_data(season, mem, resample_interval,norm_method):
    
    if season == 'concatenated':
        season_list = []
        for season in ['winter','spring','summer','autumn']:

            if norm_method == 'qmap':
                season_da = xr.open_dataarray('/nesi/project/niwa00015/queenle/data/hydro_fingerprinting/model/ECHAM5/gaussian/tasmax/seasonal/ECHAM5_all_'+season+'_tasmax_gaussian_ens'+mem+'.nc')
            elif norm_method == 'lmr':
                season_da = xr.open_dataarray('/nesi/project/niwa00015/queenle/data/hydro_fingerprinting/model/ECHAM5/local_mean_removed/tasmax/seasonal/ECHAM5_all_'+season+'_tasmax_LMR_ens'+mem+'.nc')
            elif norm_method == 'none':
                season_da = xr.open_dataarray('/nesi/project/niwa00015/queenle/data/hydro_fingerprinting/model/ECHAM5/raw/tasmax/seasonal/ECHAM5_all_'+season+'_tasmax_ens'+mem+'.nc')

            if resample_interval != 'annual':
                season_da = season_da.resample(time=resample_interval).mean()

            season_list.append(season_da)

        da = xr.concat(season_list,dim='time')
        da = da.sortby('time')

        da = da.stack(pixel=("lat", "lon"))
        da = da.dropna("pixel", how="all")        

        array = da.values.flatten()

        da.close()
    
    else:
        if norm_method == 'qmap':
            da = xr.open_dataarray('/nesi/project/niwa00015/queenle/data/hydro_fingerprinting/model/ECHAM5/gaussian/tasmax/seasonal/ECHAM5_all_'+season+'_tasmax_gaussian_ens'+mem+'.nc')

        elif norm_method == 'lmr':
            da = xr.open_dataarray('/nesi/project/niwa00015/queenle/data/hydro_fingerprinting/model/ECHAM5/local_mean_removed/tasmax/seasonal/ECHAM5_all_'+season+'_tasmax_LMR_ens'+mem+'.nc')

        elif norm_method == 'none':
            da = xr.open_dataarray('/nesi/project/niwa00015/queenle/data/hydro_fingerprinting/model/ECHAM5/raw/tasmax/seasonal/ECHAM5_all_'+season+'_tasmax_ens'+mem+'.nc')

        if resample_interval != 'annual':
            da = da.resample(time=resample_interval).mean()

        da = da.stack(pixel=("lat", "lon"))
        da = da.dropna("pixel", how="all")        

        array = da.values.flatten()

        da.close()
    
    return(array)

# %%
def get_mean_and_noise(season,scen, mem, resample_interval,norm_method):
    
    # CONCATENATED SEASONS
    if season == 'concatenated':
        ens_mean_season_list = []
        for season in ['winter','spring','summer','autumn']:
            
            if norm_method == 'qmap':
                mean_for_noise = xr.open_dataarray('/nesi/project/niwa00015/queenle/data/hydro_fingerprinting/model/ECHAM5/gaussian/tasmax/seasonal/ECHAM5_'+scen+'_'+season+'_tasmax_gaussian_ensMean.nc')

            elif norm_method == 'lmr':
                mean_for_noise = xr.open_dataarray('/nesi/project/niwa00015/queenle/data/hydro_fingerprinting/model/ECHAM5/local_mean_removed/tasmax/seasonal/ECHAM5_'+scen+'_'+season+'_tasmax_LMR_ensMean.nc')

            elif norm_method == 'none':
                mean_for_noise = xr.open_dataarray('/nesi/project/niwa00015/queenle/data/hydro_fingerprinting/model/ECHAM5/raw/tasmax/seasonal/ECHAM5_'+scen+'_'+season+'_tasmax_ensMean.nc')

            if resample_interval != 'annual':
                mean_for_noise = mean_for_noise.resample(time=resample_interval).mean()

            ens_mean_season_list.append(mean_for_noise)
            
        mean_for_noise = xr.concat(ens_mean_season_list,dim='time')
        mean_for_noise = mean_for_noise.sortby('time')
        
        noise = []
        da_list = []
        for ens_mem in range(1,51):
            
            number = '0' + str(ens_mem) if ens_mem < 10 else str(ens_mem)
            
            if number == mem:
                    continue
                    
            ens_mem_season_list = []
            for season in ['winter','spring','summer','autumn']:

                if norm_method == 'qmap':
                    ens_mem = xr.open_dataarray('/nesi/project/niwa00015/queenle/data/hydro_fingerprinting/model/ECHAM5/gaussian/tasmax/seasonal/ECHAM5_'+scen+'_'+season+'_tasmax_gaussian_ens'+number+'.nc')
                elif norm_method == 'lmr':
                    ens_mem = xr.open_dataarray('/nesi/project/niwa00015/queenle/data/hydro_fingerprinting/model/ECHAM5/local_mean_removed/tasmax/seasonal/ECHAM5_'+scen+'_'+season+'_tasmax_LMR_ens'+number+'.nc')
                elif norm_method == 'none':
                    ens_mem = xr.open_dataarray('/nesi/project/niwa00015/queenle/data/hydro_fingerprinting/model/ECHAM5/raw/tasmax/seasonal/ECHAM5_'+scen+'_'+season+'_tasmax_ens'+number+'.nc')

                if resample_interval != 'annual':
                    ens_mem = ens_mem.resample(time=resample_interval).mean()

                ens_mem_season_list.append(ens_mem)
                
            mem_da = xr.concat(ens_mem_season_list,dim='time')
            mem_da = mem_da.sortby('time')
            
            diff = mem_da - mean_for_noise

            diff = diff.stack(pixel=("lat", "lon"))# Create a MultiIndex
            diff = diff.dropna("pixel", how="all")# Drop the pixels that only have NA values.

            diff_array = diff.values.flatten()
            diff.close()

            da_list.append(mem_da)
            noise.append(diff_array)
            
        mean_for_noise.close()
        
        ens_mean = sum(da_list)/len(da_list)
        ens_mean = ens_mean.stack(pixel=("lat", "lon")) # Create a MultiIndex
        ens_mean = ens_mean.dropna("pixel", how="all") # Drop the pixels that only have NA values.

        ens_mean_array = ens_mean.values.flatten()

        ens_mean.close()
         
    # SEASONAL
    else:
        if norm_method == 'qmap':
            mean_for_noise = xr.open_dataarray('/nesi/project/niwa00015/queenle/data/hydro_fingerprinting/model/ECHAM5/gaussian/tasmax/seasonal/ECHAM5_'+scen+'_'+season+'_tasmax_gaussian_ensMean.nc')

        elif norm_method == 'lmr':
            mean_for_noise = xr.open_dataarray('/nesi/project/niwa00015/queenle/data/hydro_fingerprinting/model/ECHAM5/local_mean_removed/tasmax/seasonal/ECHAM5_'+scen+'_'+season+'_tasmax_LMR_ensMean.nc')

        elif norm_method == 'none':
            mean_for_noise = xr.open_dataarray('/nesi/project/niwa00015/queenle/data/hydro_fingerprinting/model/ECHAM5/raw/tasmax/seasonal/ECHAM5_'+scen+'_'+season+'_tasmax_ensMean.nc')

        if resample_interval != 'annual':
            mean_for_noise = mean_for_noise.resample(time=resample_interval).mean()

        noise = []
        da_list = []
        for ens_mem in range(1,51):
            number = '0' + str(ens_mem) if ens_mem < 10 else str(ens_mem)

            if number == mem:
                continue

            if norm_method == 'qmap':
                mem_da = xr.open_dataarray('/nesi/project/niwa00015/queenle/data/hydro_fingerprinting/model/ECHAM5/gaussian/tasmax/seasonal/ECHAM5_'+scen+'_'+season+'_tasmax_gaussian_ens'+number+'.nc')

            elif norm_method == 'lmr':
                mem_da = xr.open_dataarray('/nesi/project/niwa00015/queenle/data/hydro_fingerprinting/model/ECHAM5/local_mean_removed/tasmax/seasonal/ECHAM5_'+scen+'_'+season+'_tasmax_LMR_ens'+number+'.nc')

            elif norm_method == 'none':
                mem_da = xr.open_dataarray('/nesi/project/niwa00015/queenle/data/hydro_fingerprinting/model/ECHAM5/raw/tasmax/seasonal/ECHAM5_'+scen+'_'+season+'_tasmax_ens'+number+'.nc')

            if resample_interval != 'annual':
                mem_da = mem_da.resample(time=resample_interval).mean()

            diff = mem_da - mean_for_noise

            diff = diff.stack(pixel=("lat", "lon"))# Create a MultiIndex
            diff = diff.dropna("pixel", how="all")# Drop the pixels that only have NA values.

            diff_array = diff.values.flatten()
            diff.close()

            da_list.append(mem_da)
            noise.append(diff_array)

        mean_for_noise.close()

        ens_mean = sum(da_list)/len(da_list)
        ens_mean = ens_mean.stack(pixel=("lat", "lon")) # Create a MultiIndex
        ens_mean = ens_mean.dropna("pixel", how="all") # Drop the pixels that only have NA values.

        ens_mean_array = ens_mean.values.flatten()

        ens_mean.close()
    
    return((ens_mean_array, np.array(noise)))

# %%
'''
Create indivual and ensemble summary seasonal perfect model testing plots
'''

seasons = ['summer','autumn','winter','spring']

for resample_interval in ['annual']:#,'10Y','5Y']:

    ensemble_member = []
    ant_upper = []
    ant_lower = []
    ant_best = []
    nat_upper = []
    nat_lower = []
    nat_best = []
    season = []
    for ens_mem in range(1,51):

        number = '0' + str(ens_mem) if ens_mem < 10 else str(ens_mem)

        fig,axs = plt.subplots(2,2, figsize=(12,10))#,sharey=True)
        axs = axs.flatten()

        for i,s in enumerate(seasons):    

            IDL.retall

            all_ens_mean,noise_all = get_mean_and_noise(s,'all',number,resample_interval,'qmap')
            nat_ens_mean,noise_nat = get_mean_and_noise(s,'nat',number,resample_interval,'qmap')

            data_obs = get_obs_data(s, number, resample_interval,'qmap')

            data_scen = np.array([all_ens_mean,nat_ens_mean])

            # double noise
            #data_noise_1 = np.concatenate((noise_all,noise_nat))
            #data_noise_2 = np.concatenate((noise_all,noise_nat))
            
            data_noise_1 = np.concatenate((noise_all[:24],noise_nat[:25]))
            data_noise_2 = np.concatenate((noise_all[24:],noise_nat[25:]))
            
            trunc = np.array([i for i in range(3,48)])
            #trunc = np.array([i for i in range(3,96)])

            IDL.data_obs = data_obs
            IDL.data_scen = data_scen
            IDL.data_noise_1 = data_noise_1
            IDL.data_noise_2 = data_noise_2
            IDL.trunc = trunc
            IDL.scan_beta_est = []
            IDL.scan_p_resid = []
            IDL.scan_resid_sumsq = []
            IDL.p_resid = []
            IDL.resid_sumsq = []
            IDL.noise_singval = []
            IDL.z_best = []

            IDL.run("gendetec, data_obs, data_scen, data_noise_1, beta_est, scan_resid_sumsq=scan_resid_sumsq, \
                    data_noise_2=data_noise_2,transform=['1*0','1*0+1*1'], trunc=trunc, scan_beta_est=scan_beta_est,\
                    scan_p_resid=scan_p_resid,noise_singval=noise_singval,z_best=z_best")

            beta_est = IDL.beta_est
            scan_beta_est = IDL.scan_beta_est
            scan_p_resid = IDL.scan_p_resid
            scan_resid_sumsq = IDL.scan_resid_sumsq
            noise_singval = IDL.noise_singval
            z_best = IDL.z_best

            for j in range(len(scan_beta_est)):

                beta_est = scan_beta_est[j]

                best_1,low_1,up_1 = beta_est[0][0],beta_est[1][0],beta_est[2][0]
                best_2,low_2,up_2 = beta_est[0][1],beta_est[1][1],beta_est[2][1]

                axs[i].scatter([j+3]*3,[low_2,best_2,up_2],c='blue',alpha=0.7,label='nat' if j == 0 else '')
                axs[i].scatter([j+3]*3,[low_1,best_1,up_1],c='red',label='ant' if j == 0 else '')

                axs[i].vlines(j+3,low_2,up_2,colors=['blue'])
                axs[i].vlines(j+3,low_1,up_1,colors=['red'])
                
                axs[i].axhline(0,-0.5,1.5)
                axs[i].axhline(1,-0.5,1.5)
                
            t = 36
            ensemble_member.append(number)
            ant_upper.append(scan_beta_est[t-3][2][0])
            ant_lower.append(scan_beta_est[t-3][1][0])
            ant_best.append(scan_beta_est[t-3][0][0])
            nat_upper.append(scan_beta_est[t-3][2][1])
            nat_lower.append(scan_beta_est[t-3][1][1])
            nat_best.append(scan_beta_est[t-3][0][1])
            season.append(s)

            axs[i].set_title(s)

            axs[i].legend()
            #axs[i].set_ylim(-4,5)

        plt.savefig('/nesi/project/niwa00015/queenle/plots/perfect_model/ECHAM5/tasmax/qmap/seasonal/'+resample_interval+'/' + 'PM_ens_' + number + '.png')

        plt.close(fig)
        
    df = pd.DataFrame({'ensemble_member':ensemble_member,
                      'season':season,
                      'ant_upper':ant_upper,
                      'ant_lower':ant_lower,
                      'ant_best':ant_best,
                      'nat_upper':nat_upper,
                      'nat_lower':nat_lower,
                      'nat_best':nat_best})

    for sort_type in ['nat_best','ant_best']:
        
        fig,axs = plt.subplots(2,2, figsize=(12,10))
        axs = axs.flatten()
        
        for i,s in enumerate(seasons):
            
            sorted_df = df.loc[df['season'] == s].sort_values(by=sort_type)
            
            axs[i].scatter([i for i in range(len(sorted_df.nat_upper))],sorted_df.nat_upper,c='blue',label='nat')
            axs[i].scatter([i for i in range(len(sorted_df.nat_lower))],sorted_df.nat_lower,c='blue',label='')
            axs[i].scatter([i for i in range(len(sorted_df.nat_best))],sorted_df.nat_best,c='blue',label='')

            axs[i].scatter([i for i in range(len(sorted_df.ant_upper))],sorted_df.ant_upper,c='red',label='ant')
            axs[i].scatter([i for i in range(len(sorted_df.ant_lower))],sorted_df.ant_lower,c='red',label='')
            axs[i].scatter([i for i in range(len(sorted_df.ant_best))],sorted_df.ant_best,c='red',label='')

            axs[i].vlines([i for i in range(len(sorted_df.nat_lower))],sorted_df.nat_lower,sorted_df.nat_upper,colors=['blue'],label='')
            axs[i].vlines([i for i in range(len(sorted_df.ant_lower))],sorted_df.ant_lower,sorted_df.ant_upper,colors=['red'],label='')

            del sorted_df
            
            axs[i].axhline(0,-0.5,1.5)
            axs[i].axhline(1,-0.5,1.5)

            axs[i].set_title(s + ', trunc = ' + str(t))

            axs[i].legend()
            
            #axs[i].set_ylim(-2,3)

        del df
        
        plt.savefig('/nesi/project/niwa00015/queenle/plots/perfect_model/ECHAM5/tasmax/qmap/seasonal/' + resample_interval + '/' + 'PM_ensemble_summary_'+sort_type+'_sort.png')

        plt.close(fig)
# Out:
# Exception ignored in: <module 'collections.abc' from '/opt/nesi/CS500_centos7_skl/Anaconda3/5.2.0-GCC-7.1.0/lib/python3.6/collections/abc.py'>
# Traceback (most recent call last):
#   File "<string>", line 1, in <module>
# KeyboardInterrupt
# /opt/nesi/CS500_centos7_skl/Anaconda3/5.2.0-GCC-7.1.0/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: Cython module failed to patch module with custom type
#   return f(*args, **kwds)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-00f2b1e70a53> in <module>()
#      26             IDL.retall
#      27
# ---> 28             all_ens_mean,noise_all = get_mean_and_noise(s,'all',number,resample_interval,'qmap')
#      29             nat_ens_mean,noise_nat = get_mean_and_noise(s,'nat',number,resample_interval,'qmap')
#      30
#
# <ipython-input-4-38f897af61f7> in get_mean_and_noise(season, scen, mem, resample_interval, norm_method)
#      94
#      95             if norm_method == 'qmap':
# ---> 96                 mem_da = xr.open_dataarray('/nesi/project/niwa00015/queenle/data/hydro_fingerprinting/model/ECHAM5/gaussian/tasmax/seasonal/ECHAM5_'+scen+'_'+season+'_tasmax_gaussian_ens'+number+'.nc')
#      97
#      98             elif norm_method == 'lmr':
#
# ~/.local/lib/python3.6/site-packages/xarray/backends/api.py in open_dataarray(filename_or_obj, group, decode_cf, mask_and_scale, decode_times, autoclose, concat_characters, decode_coords, engine, chunks, lock, cache, drop_variables, backend_kwargs, use_cftime, decode_timedelta)
#     715         backend_kwargs=backend_kwargs,
#     716         use_cftime=use_cftime,
# --> 717         decode_timedelta=decode_timedelta,
#     718     )
#     719
#
# ~/.local/lib/python3.6/site-packages/xarray/backends/api.py in open_dataset(filename_or_obj, group, decode_cf, mask_and_scale, decode_times, autoclose, concat_characters, decode_coords, engine, chunks, lock, cache, drop_variables, backend_kwargs, use_cftime, decode_timedelta)
#     573
#     574     with close_on_error(store):
# --> 575         ds = maybe_decode_store(store, chunks)
#     576
#     577     # Ensure source filename always stored in dataset object (GH issue #2550)
#
# ~/.local/lib/python3.6/site-packages/xarray/backends/api.py in maybe_decode_store(store, chunks)
#     477             drop_variables=drop_variables,
#     478             use_cftime=use_cftime,
# --> 479             decode_timedelta=decode_timedelta,
#     480         )
#     481
#
# ~/.local/lib/python3.6/site-packages/xarray/conventions.py in decode_cf(obj, concat_characters, mask_and_scale, decode_times, decode_coords, drop_variables, use_cftime, decode_timedelta)
#     598         decode_timedelta=decode_timedelta,
#     599     )
# --> 600     ds = Dataset(vars, attrs=attrs)
#     601     ds = ds.set_coords(coord_names.union(extra_coords).intersection(vars))
#     602     ds._file_obj = file_obj
#
# ~/.local/lib/python3.6/site-packages/xarray/core/dataset.py in __init__(self, data_vars, coords, attrs)
#     629
#     630         variables, coord_names, dims, indexes, _ = merge_data_and_coords(
# --> 631             data_vars, coords, compat="broadcast_equals"
#     632         )
#     633
#
# ~/.local/lib/python3.6/site-packages/xarray/core/merge.py in merge_data_and_coords(data, coords, compat, join)
#     466     indexes = dict(_extract_indexes_from_coords(coords))
#     467     return merge_core(
# --> 468         objects, compat, join, explicit_coords=explicit_coords, indexes=indexes
#     469     )
#     470
#
# ~/.local/lib/python3.6/site-packages/xarray/core/merge.py in merge_core(objects, compat, join, combine_attrs, priority_arg, explicit_coords, indexes, fill_value)
#     592         coerced, join=join, copy=False, indexes=indexes, fill_value=fill_value
#     593     )
# --> 594     collected = collect_variables_and_indexes(aligned)
#     595
#     596     prioritized = _get_priority_vars_and_indexes(aligned, priority_arg, compat=compat)
#
# ~/.local/lib/python3.6/site-packages/xarray/core/merge.py in collect_variables_and_indexes(list_of_mappings)
#     276                 append_all(coords, indexes)
#     277
# --> 278             variable = as_variable(variable, name=name)
#     279             if variable.dims == (name,):
#     280                 variable = variable.to_index_variable()
#
# ~/.local/lib/python3.6/site-packages/xarray/core/variable.py in as_variable(obj, name)
#     158                 "dimensions." % (name, obj.dims)
#     159             )
# --> 160         obj = obj.to_index_variable()
#     161
#     162     return obj
#
# ~/.local/lib/python3.6/site-packages/xarray/core/variable.py in to_index_variable(self)
#     527         """Return this variable as an xarray.IndexVariable"""
#     528         return IndexVariable(
# --> 529             self.dims, self._data, self._attrs, encoding=self._encoding, fastpath=True
#     530         )
#     531
#
# ~/.local/lib/python3.6/site-packages/xarray/core/variable.py in __init__(self, dims, data, attrs, encoding, fastpath)
#    2410         # Unlike in Variable, always eagerly load values into memory
#    2411         if not isinstance(self._data, PandasIndexAdapter):
# -> 2412             self._data = PandasIndexAdapter(self._data)
#    2413
#    2414     def __dask_tokenize__(self):
#
# ~/.local/lib/python3.6/site-packages/xarray/core/indexing.py in __init__(self, array, dtype)
#    1395
#    1396     def __init__(self, array: Any, dtype: DTypeLike = None):
# -> 1397         self.array = utils.safe_cast_to_index(array)
#    1398         if dtype is None:
#    1399             if isinstance(array, pd.PeriodIndex):
#
# ~/.local/lib/python3.6/site-packages/xarray/core/utils.py in safe_cast_to_index(array)
#     102         if hasattr(array, "dtype") and array.dtype.kind == "O":
#     103             kwargs["dtype"] = object
# --> 104         index = pd.Index(np.asarray(array), **kwargs)
#     105     return _maybe_cast_to_cftimeindex(index)
#     106
#
# ~/.local/lib/python3.6/site-packages/numpy/core/_asarray.py in asarray(a, dtype, order)
#      83
#      84     """
# ---> 85     return array(a, dtype, copy=False, order=order)
#      86
#      87
#
# ~/.local/lib/python3.6/site-packages/xarray/core/indexing.py in __array__(self, dtype)
#     566     def __array__(self, dtype=None):
#     567         array = as_indexable(self.array)
# --> 568         return np.asarray(array[self.key], dtype=None)
#     569
#     570     def transpose(self, order):
#
# ~/.local/lib/python3.6/site-packages/numpy/core/_asarray.py in asarray(a, dtype, order)
#      83
#      84     """
# ---> 85     return array(a, dtype, copy=False, order=order)
#      86
#      87
#
# ~/.local/lib/python3.6/site-packages/xarray/coding/variables.py in __array__(self, dtype)
#      68
#      69     def __array__(self, dtype=None):
# ---> 70         return self.func(self.array)
#      71
#      72     def __repr__(self):
#
# ~/.local/lib/python3.6/site-packages/xarray/coding/times.py in decode_cf_datetime(num_dates, units, calendar, use_cftime)
#     185     cftime.num2date
#     186     """
# --> 187     num_dates = np.asarray(num_dates)
#     188     flat_num_dates = num_dates.ravel()
#     189     if calendar is None:
#
# ~/.local/lib/python3.6/site-packages/numpy/core/_asarray.py in asarray(a, dtype, order)
#      83
#      84     """
# ---> 85     return array(a, dtype, copy=False, order=order)
#      86
#      87
#
# ~/.local/lib/python3.6/site-packages/xarray/core/indexing.py in __array__(self, dtype)
#     566     def __array__(self, dtype=None):
#     567         array = as_indexable(self.array)
# --> 568         return np.asarray(array[self.key], dtype=None)
#     569
#     570     def transpose(self, order):
#
# ~/.local/lib/python3.6/site-packages/xarray/backends/netCDF4_.py in __getitem__(self, key)
#      71     def __getitem__(self, key):
#      72         return indexing.explicit_indexing_adapter(
# ---> 73             key, self.shape, indexing.IndexingSupport.OUTER, self._getitem
#      74         )
#      75
#
# ~/.local/lib/python3.6/site-packages/xarray/core/indexing.py in explicit_indexing_adapter(key, shape, indexing_support, raw_indexing_method)
#     851     """
#     852     raw_key, numpy_indices = decompose_indexer(key, shape, indexing_support)
# --> 853     result = raw_indexing_method(raw_key.tuple)
#     854     if numpy_indices.tuple:
#     855         # index the loaded np.ndarray
#
# ~/.local/lib/python3.6/site-packages/xarray/backends/netCDF4_.py in _getitem(self, key)
#      83             with self.datastore.lock:
#      84                 original_array = self.get_array(needs_lock=False)
# ---> 85                 array = getitem(original_array, key)
#      86         except IndexError:
#      87             # Catch IndexError in netCDF4 and return a more informative
#
# KeyboardInterrupt:

# %%
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-00cf07b74dcd> in <module>()
# ----> 1 df
#
# NameError: name 'df' is not defined

# %%
'''
Write ensemble summary csv files
'''

seasons = ['summer','autumn','winter','spring']

for resample_interval in ['10Y','5Y']:#'annual',

    ensemble_member = []
    ant_upper = []
    ant_lower = []
    ant_best = []
    nat_upper = []
    nat_lower = []
    nat_best = []
    season = []
    for ens_mem in range(1,51):

        number = '0' + str(ens_mem) if ens_mem < 10 else str(ens_mem)

        for i,s in enumerate(seasons):    

            IDL.retall

            all_ens_mean,noise_all = get_mean_and_noise(s,'all',number,resample_interval,'qmap')
            nat_ens_mean,noise_nat = get_mean_and_noise(s,'nat',number,resample_interval,'qmap')

            data_obs = get_obs_data(s, number, resample_interval,'qmap')

            data_scen = np.array([all_ens_mean,nat_ens_mean])

            data_noise_1 = np.concatenate((noise_all[:24],noise_nat[:25]))
            data_noise_2 = np.concatenate((noise_all[24:],noise_nat[25:]))
            
            trunc = 36

            IDL.data_obs = data_obs
            IDL.data_scen = data_scen
            IDL.data_noise_1 = data_noise_1
            IDL.data_noise_2 = data_noise_2
            IDL.trunc = trunc

            IDL.run("gendetec, data_obs, data_scen, data_noise_1, beta_est, \
                    data_noise_2=data_noise_2,transform=['1*0','1*0+1*1'], trunc=trunc")

            beta_est = IDL.beta_est

            ensemble_member.append(number)
            ant_upper.append(beta_est[2][0])
            ant_lower.append(beta_est[1][0])
            ant_best.append(beta_est[0][0])
            nat_upper.append(beta_est[2][1])
            nat_lower.append(beta_est[1][1])
            nat_best.append(beta_est[0][1])
            season.append(s)
        
    df = pd.DataFrame({'ensemble_member':ensemble_member,
                      'season':season,
                      'ant_upper':ant_upper,
                      'ant_lower':ant_lower,
                      'ant_best':ant_best,
                      'nat_upper':nat_upper,
                      'nat_lower':nat_lower,
                      'nat_best':nat_best})

    df.to_csv("/nesi/project/niwa00015/queenle/data/hydro_fingerprinting/model/ECHAM5/summary_csv/tasmax_" +resample_interval + "_trunc_" + str(trunc) + ".csv")
    
    del df

# %%
df
# Out:
#     ensemble_member  season  ant_upper  ant_lower  ant_best  nat_upper  \
# 0                01  summer   1.638015  -0.428148  0.604933   1.580710
# 1                01  autumn   1.698819  -0.314611  0.692104   1.296036
# 2                01  winter   2.077538  -0.053781  1.011879   1.419939
# 3                01  spring   2.195701  -0.040548  1.077577   1.105544
# 4                02  summer   2.033917  -0.185929  0.923994   1.378337
# ..              ...     ...        ...        ...       ...        ...
# 195              49  spring   2.394183   0.208460  1.301321   1.626859
# 196              50  summer   1.302604  -0.820742  0.240931   1.125052
# 197              50  autumn   1.810682  -0.166039  0.822321   1.306219
# 198              50  winter   2.558869   0.435498  1.497184   1.691412
# 199              50  spring   2.023139  -0.179739  0.921700   1.317032
#
#      nat_lower  nat_best
# 0     0.772830  1.176770
# 1     0.415339  0.855688
# 2     0.507361  0.963650
# 3     0.411283  0.758413
# 4     0.551477  0.964907
# ..         ...       ...
# 195   0.931634  1.279246
# 196   0.314578  0.719815
# 197   0.501441  0.903830
# 198   0.741838  1.216625
# 199   0.611705  0.964368
#
# [200 rows x 8 columns]

# %%
df.to_csv("/nesi/project/niwa00015/queenle/data/hydro_fingerprinting/model/ECHAM5/summary_csv/tasmax_" +resample_interval + "_trunc_" + str(trunc) + ".csv")
