# %%
import xarray as xr

# %%
ds = xr.open_dataset('d4PDF_GCM/HPB/m001/tasmax_Aday_d4PDF_HPB_m001_196412.nc')

# %%
ds.ta.mean('time')
# Out:
# <xarray.DataArray 'ta' (lev: 1, lat: 92, lon: 59)>
# array([[[295.2914 , 295.23477, 295.18933, ..., 298.20956, 299.43936,
#          296.9086 ],
#         [295.0018 , 294.93607, 294.88794, ..., 297.90298, 298.57236,
#          296.30142],
#         [294.71512, 294.64453, 294.59735, ..., 297.37228, 299.6096 ,
#          298.4415 ],
#         ...,
#         [251.65323, 251.5    , 251.24005, ..., 245.19286, 245.14157,
#          245.09918],
#         [250.36237, 250.19624, 249.95052, ..., 245.11937, 245.29868,
#          245.53754],
#         [249.69582, 249.62173, 249.504  , ..., 245.5789 , 245.90106,
#          246.09189]]], dtype=float32)
# Coordinates:
#   * lon      (lon) float64 222.8 223.3 223.9 224.4 ... 253.7 254.2 254.8 255.4
#   * lat      (lat) float64 19.94 20.5 21.06 21.62 ... 69.36 69.92 70.48 71.05
#   * lev      (lev) float64 1e+03

# %%
ds.ta.isel(time=0).plot()
